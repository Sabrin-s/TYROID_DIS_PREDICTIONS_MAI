# %%
import torch
import torch.nn as nn
from PIL import Image
import torchvision.transforms as transforms
from transformers import BartModel, BartTokenizer
from torchvision import models
import pandas as pd

# Define the MultiModalClassifier class
class MultiModalClassifier(nn.Module):
    def __init__(self, text_model, image_model, text_feat_dim, image_feat_dim, hidden_dim, num_classes):
        super(MultiModalClassifier, self).__init__()
        self.text_model = text_model
        self.image_model = image_model

        # Linear layers to project modality-specific features to a common hidden space
        self.text_fc = nn.Linear(text_feat_dim, hidden_dim)
        self.image_fc = nn.Linear(image_feat_dim, hidden_dim)

        # Final classifier head that outputs logits for each class
        self.classifier = nn.Linear(hidden_dim, num_classes)

    def forward(self, text_input=None, image_input=None):
        features = None

        if text_input is not None:
            # Remove 'labels' if present so that BART doesn't receive an unexpected key
            text_input_filtered = {k: v for k, v in text_input.items() if k != "labels"}
            text_outputs = self.text_model(**text_input_filtered)
            # Mean pooling over the sequence dimension (dim=1)
            pooled_text = text_outputs.last_hidden_state.mean(dim=1)
            text_features = self.text_fc(pooled_text)
            features = text_features if features is None else features + text_features

        if image_input is not None:
            # The image model should output a feature vector (with final fc replaced by Identity)
            image_features = self.image_model(image_input)
            image_features = self.image_fc(image_features)
            features = image_features if features is None else features + image_features

        # If both modalities are provided, average their features
        if (text_input is not None) and (image_input is not None):
            features = features / 2

        logits = self.classifier(features)
        return logits

# Load the tokenizer
model_name = "facebook/bart-base"
tokenizer = BartTokenizer.from_pretrained(model_name)

# Define image transformations for inference
image_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load the CSV file to get the label list
text_df = pd.read_csv("data.csv")
label_list = text_df['label'].unique().tolist()

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_path = "multimodal_model.pth"

# Load the pre-trained ResNet18 model and replace its fc layer with Identity
image_model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
image_model.fc = nn.Identity()

# Create the MultiModalClassifier using the modified image model
model = MultiModalClassifier(
    text_model=BartModel.from_pretrained(model_name),
    image_model=image_model,
    text_feat_dim=768,   # typically 768 for bart-base
    image_feat_dim=512,  # typically 512 for resnet18 after replacing fc
    hidden_dim=512,
    num_classes=len(label_list)
)

# Load the saved state dict
model.load_state_dict(torch.load(model_path, map_location=device))
model.to(device)
model.eval()

# Mapping from label IDs to label names
label2id = {label: idx for idx, label in enumerate(label_list)}
id2label = {idx: label for label, idx in label2id.items()}

def inference_text(model, tokenizer, text, device, max_length=128):
    """Perform inference on text input only."""
    model.eval()
    encoding = tokenizer(
        text,
        padding="max_length",
        truncation=True,
        max_length=max_length,
        return_tensors="pt"
    )
    # Move encoding to device
    for key in encoding:
        encoding[key] = encoding[key].to(device)
    with torch.no_grad():
        logits = model(text_input=encoding, image_input=None)
    pred_id = torch.argmax(logits, dim=1).item()
    return id2label[pred_id]

def inference_image(model, image_path, transform, device):
    """Perform inference on an image input only."""
    model.eval()
    image = Image.open(image_path).convert("RGB")
    image = transform(image).unsqueeze(0)  # add batch dimension
    image = image.to(device)
    with torch.no_grad():
        logits = model(text_input=None, image_input=image)
    pred_id = torch.argmax(logits, dim=1).item()
    return id2label[pred_id]

def inference_both(model, tokenizer, text, image_path, transform, device, max_length=128):
    """Perform inference using both text and image inputs."""
    model.eval()
    # Process text input
    encoding = tokenizer(
        text,
        padding="max_length",
        truncation=True,
        max_length=max_length,
        return_tensors="pt"
    )
    for key in encoding:
        encoding[key] = encoding[key].to(device)
    # Process image input
    image = Image.open(image_path).convert("RGB")
    image = transform(image).unsqueeze(0)
    image = image.to(device)
    with torch.no_grad():
        logits = model(text_input=encoding, image_input=image)
    pred_id = torch.argmax(logits, dim=1).item()
    return id2label[pred_id]

# Example inference usage
sample_text = "neck mass, shortness of breath, rapid thyroid growth, fever"
sample_image_path = r"F:\ABDUL\ABDUL 2024\TYROID_DIS_PREDICTIONS_MAI\IMAGES_DATASET\train\malignant\malignant-19-_png_jpg.rf.b56e0e1b4f51ac3c2b1f1ff9b74a7339.jpg"

# Text inference
predicted_label_text = inference_text(model, tokenizer, sample_text, device)
print(f"Predicted label from text: {predicted_label_text}")

# Image inference
predicted_label_image = inference_image(model, sample_image_path, image_transforms, device)
print(f"Predicted label from image: {predicted_label_image}")

# Combined inference
predicted_label_both = inference_both(model, tokenizer, sample_text, sample_image_path, image_transforms, device)
print(f"Predicted label from both modalities: {predicted_label_both}")

# %%
import torch
import torch.nn as nn
from PIL import Image
import torchvision.transforms as transforms
from transformers import BartModel, BartTokenizer
from torchvision import models
import pandas as pd
from g4f.client import Client

# Define the MultiModalClassifier class
class MultiModalClassifier(nn.Module):
    def __init__(self, text_model, image_model, text_feat_dim, image_feat_dim, hidden_dim, num_classes):
        super(MultiModalClassifier, self).__init__()
        self.text_model = text_model
        self.image_model = image_model

        # Linear layers to project modality-specific features to a common hidden space
        self.text_fc = nn.Linear(text_feat_dim, hidden_dim)
        self.image_fc = nn.Linear(image_feat_dim, hidden_dim)

        # Final classifier head that outputs logits for each class
        self.classifier = nn.Linear(hidden_dim, num_classes)

    def forward(self, text_input=None, image_input=None):
        features = None

        if text_input is not None:
            # Remove 'labels' if present so that BART doesn't receive an unexpected key
            text_input_filtered = {k: v for k, v in text_input.items() if k != "labels"}
            text_outputs = self.text_model(**text_input_filtered)
            # Mean pooling over the sequence dimension (dim=1)
            pooled_text = text_outputs.last_hidden_state.mean(dim=1)
            text_features = self.text_fc(pooled_text)
            features = text_features if features is None else features + text_features

        if image_input is not None:
            # The image model should output a feature vector (with final fc replaced by Identity)
            image_features = self.image_model(image_input)
            image_features = self.image_fc(image_features)
            features = image_features if features is None else features + image_features

        # If both modalities are provided, average their features
        if (text_input is not None) and (image_input is not None):
            features = features / 2

        logits = self.classifier(features)
        return logits

# Load the tokenizer
model_name = "facebook/bart-base"
tokenizer = BartTokenizer.from_pretrained(model_name)

# Define image transformations for inference
image_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load the CSV file to get the label list
text_df = pd.read_csv("data.csv")
label_list = text_df['label'].unique().tolist()

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_path = "multimodal_model.pth"

# Load the pre-trained ResNet18 model and replace its fc layer with Identity
image_model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
image_model.fc = nn.Identity()

# Create the MultiModalClassifier using the modified image model
model = MultiModalClassifier(
    text_model=BartModel.from_pretrained(model_name),
    image_model=image_model,
    text_feat_dim=768,   # typically 768 for bart-base
    image_feat_dim=512,  # typically 512 for resnet18 after replacing fc
    hidden_dim=512,
    num_classes=len(label_list)
)

# Load the saved state dict
model.load_state_dict(torch.load(model_path, map_location=device))
model.to(device)
model.eval()

# Mapping from label IDs to label names
label2id = {label: idx for idx, label in enumerate(label_list)}
id2label = {idx: label for label, idx in label2id.items()}

def inference_text(model, tokenizer, text, device, max_length=128):
    """Perform inference on text input only."""
    model.eval()
    encoding = tokenizer(
        text,
        padding="max_length",
        truncation=True,
        max_length=max_length,
        return_tensors="pt"
    )
    # Move encoding to device
    for key in encoding:
        encoding[key] = encoding[key].to(device)
    with torch.no_grad():
        logits = model(text_input=encoding, image_input=None)
    pred_id = torch.argmax(logits, dim=1).item()
    return id2label[pred_id], text

def inference_image(model, image_path, transform, device):
    """Perform inference on an image input only."""
    model.eval()
    image = Image.open(image_path).convert("RGB")
    image = transform(image).unsqueeze(0)  # add batch dimension
    image = image.to(device)
    with torch.no_grad():
        logits = model(text_input=None, image_input=image)
    pred_id = torch.argmax(logits, dim=1).item()
    return id2label[pred_id], image_path

def inference_both(model, tokenizer, text, image_path, transform, device, max_length=128):
    """Perform inference using both text and image inputs."""
    model.eval()
    # Process text input
    encoding = tokenizer(
        text,
        padding="max_length",
        truncation=True,
        max_length=max_length,
        return_tensors="pt"
    )
    for key in encoding:
        encoding[key] = encoding[key].to(device)
    # Process image input
    image = Image.open(image_path).convert("RGB")
    image = transform(image).unsqueeze(0)
    image = image.to(device)
    with torch.no_grad():
        logits = model(text_input=encoding, image_input=image)
    pred_id = torch.argmax(logits, dim=1).item()
    return id2label[pred_id], text, image_path

def generate_report(predicted_label, text, image_path):
    """Generate a diagnosis and solutions report using the gpt-4o-mini model."""
    client = Client()
    prompt = f"Based on the symptoms '{text}' and the image '{image_path}', the predicted label is '{predicted_label}'. Generate a diagnosis and solutions report for Thyroid Disease."
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        web_search=False
    )
    return response.choices[0].message.content

# Example inference usage
sample_text = "neck mass, shortness of breath, rapid thyroid growth, fever"
sample_image_path = r"F:\ABDUL\ABDUL 2024\TYROID_DIS_PREDICTIONS_MAI\IMAGES_DATASET\train\malignant\malignant-19-_png_jpg.rf.b56e0e1b4f51ac3c2b1f1ff9b74a7339.jpg"

# Text inference
predicted_label_text, text_input = inference_text(model, tokenizer, sample_text, device)
print(f"Predicted label from text: {predicted_label_text}")
report_text = generate_report(predicted_label_text, text_input, "")
print(f"Diagnosis and solutions report from text: {report_text}")

# Image inference
predicted_label_image, image_input = inference_image(model, sample_image_path, image_transforms, device)
print(f"Predicted label from image: {predicted_label_image}")
report_image = generate_report(predicted_label_image, "", image_input)
print(f"Diagnosis and solutions report from image: {report_image}")

# Combined inference
predicted_label_both, text_input, image_input = inference_both(model, tokenizer, sample_text, sample_image_path, image_transforms, device)
print(f"Predicted label from both modalities: {predicted_label_both}")
report_both = generate_report(predicted_label_both, text_input, image_input)
print(f"Diagnosis and solutions report from both modalities: {report_both}")
# Out:
# Predicted label from text: malignant
# Diagnosis and solutions report from text: ## Diagnosis and Solutions Report for Thyroid Disease
#
# ### Patient Symptoms
# - Neck mass
# - Shortness of breath
# - Rapid thyroid growth
# - Fever
#
# ### Clinical Assessment
# Based on the presented symptoms, the clinical suspicion leans towards a malignant thyroid condition, possibly thyroid cancer, which could manifest as a rapidly growing nodule in the presence of systemic symptoms such as fever and shortness of breath.
#
# ### Differential Diagnosis
# 1. **Thyroid Cancer** - Given the rapid growth of the thyroid and concerning symptoms.
# 2. **Thyroiditis** - Inflammatory conditions like Hashimoto’s or subacute thyroiditis could cause fever and neck swelling.
# 3. **Benign Thyroid Nodules** - Some benign growths can occasionally cause compression symptoms.
# 4. **Lymphoma of the Thyroid** - Rare but could present with a neck mass and systemic symptoms.
#
# ### Diagnostic Workup
# 1. **Physical Examination**:
#    - Thorough examination of the neck for size, tenderness, and mobility of the mass.
# 2. **Ultrasound of the Thyroid**:
#    - To assess size, composition (solid vs. cystic), and blood flow.
# 3. **Thyroid Function Tests**:
#    - TSH, Free T4, and Total T3 levels.
# 4. **Fine Needle Aspiration Biopsy (FNAB)**:
#    - To obtain cytological diagnosis of the thyroid mass.
# 5. **CT Scan or MRI of the Neck**:
#    - To visualize the extent of the mass and assess for any compressive symptoms or metastasis.
#
# ### Potential Diagnosis
# - **Malignant Thyroid Neoplasm** (e.g., Papillary Thyroid Carcinoma or Anaplastic Thyroid Carcinoma, depending on the acceleration and age of the patient).
#
# ### Treatment Solutions
# 1. **Surgical Intervention**:
#    - Total or partial thyroidectomy depending on the extent of the disease.
#    - Consideration of neck dissection if lymphatic spread is suspected.
#
# 2. **Radioactive Iodine Treatment**:
#    - For certain types of thyroid cancer, to ablate any remaining thyroid tissue post-surgery or treat metastatic disease.
#
# 3. **External Beam Radiation Therapy**:
#    - In cases where surgery is not possible or for palliative reasons.
#
# 4. **Chemotherapy**:
#    - For advanced or metastatic disease; typically involves multi-agent regimens according to established guidelines.
#
# 5. **Supportive Care**:
#    - Manage symptoms of shortness of breath with bronchodilators if needed.
#    - Treat any systemic symptoms such as fever with analgesics and antifebrile agents.
#    - Nutritional support and psychological counseling.
#
# ### Follow-Up
# - Regular follow-up with endocrinology and oncology.
# - Monitor for recurrence with periodic ultrasounds and thyroid function tests.
# - Consider genetic counseling if familial thyroid disease is suspected.
#
# ### Conclusion
# Given the rapid growth of the thyroid mass along with systemic symptoms, a malignant process should be strongly considered. Detailed investigations will aid in confirming the diagnosis, and appropriate surgical and medical management options should be considered promptly. Regular follow-up is essential for managing this condition effectively.
# Predicted label from image: malignant
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\selectors.py:74: RuntimeWarning: coroutine 'async_generator_to_list' was never awaited
#   raise KeyError("{!r} is not registered".format(fileobj)) from None
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Diagnosis and solutions report from image: ## Diagnosis and Solutions Report for Thyroid Disease
#
# ### Patient Information
# - **Patient ID:** [Your ID]
# - **Date:** February 23, 2025
# - **Image Reference:** malignant-19 (path: F:\ABDUL\ABDUL 2024\TYROID_DIS_PREDICTIONS_MAI\IMAGES_DATASET\train\malignant\malignant-19-_png_jpg.rf.b56e0e1b4f51ac3c2b1f1ff9b74a7339.jpg)
#
# ### Diagnosis
# Based on the provided symptoms and the analysis of the image, the predicted diagnosis is **Malignant Thyroid Disease**.
#
# #### Symptoms
# While the specific symptoms were not detailed in your query, common symptoms of malignant thyroid conditions may include:
# - A lump in the neck (goiter).
# - Difficulty swallowing or breathing due to pressure.
# - Changes in voice (hoarseness).
# - Swollen lymph nodes in the neck.
# - Unexplained weight loss.
#
# ### Types of Malignant Thyroid Tumors
# 1. **Papillary Thyroid Carcinoma (PTC)**: Most common form, generally grows slowly.
# 2. **Follicular Thyroid Carcinoma (FTC)**: More aggressive than PTC.
# 3. **Medullary Thyroid Carcinoma (MTC)**: Often associated with genetic syndromes.
# 4. **Anaplastic Thyroid Carcinoma (ATC)**: Rare but very aggressive.
#
# ### Recommended Diagnostic Tests
# 1. **Ultrasound of the Neck**: Evaluate the structure and size of the thyroid nodules.
# 2. **Fine-Needle Aspiration Biopsy (FNAB)**: To obtain tissue for pathological examination.
# 3. **Thyroid Function Tests**: To assess levels of TSH, T3, and T4 hormones.
# 4. **Imaging**: CT/MRI may be used for staging or assessing local invasion if indicated.
#
# ### Treatment Options
# #### Surgical Intervention
# - **Thyroidectomy**: Complete or partial removal of the thyroid gland may be necessary depending on the extent of malignancy.
#
# #### Radioactive Iodine Therapy
# - Used primarily for certain types of thyroid cancer post-surgery to eliminate residual cancer cells.
#
# #### External Beam Radiation Therapy
# - May be considered, especially for non-responsive tumors or higher-risk patients.
#
# #### Targeted Therapy
# - If mutations (e.g., in the RET gene in MTC) are present, targeted therapies may be an option.
#
# ### Follow-Up and Monitoring
# - Regular follow-up appointments for monitoring hormone levels and for any recurrence of disease.
# - Lifelong thyroid hormone replacement therapy may be required if the entire thyroid is removed.
#
# ### Lifestyle and Supportive Care
# - Maintain a healthy diet rich in fruits, vegetables, and whole grains.
# - Consult a nutritionist for personalized dietary recommendations.
# - Join support groups for emotional and psychological support.
#
# ### Conclusion
# This report should be discussed with the patient’s healthcare provider to confirm the diagnosis, explore treatment options, and develop a personalized care plan. Early detection and intervention are crucial for improving outcomes in cases of malignant thyroid disease.
# Predicted label from both modalities: malignant
# Diagnosis and solutions report from both modalities: ### Diagnosis and Solutions Report for Thyroid Disease
#
# #### Patient Information
# - **Symptoms**:
#   - Neck mass
#   - Shortness of breath
#   - Rapid thyroid growth
#   - Fever
#
# #### Clinical Findings
# Based on the symptoms presented, the following clinical findings are noted:
#
# 1. **Neck Mass**: The presence of a mass in the neck can indicate an enlargement of the thyroid gland (goiter) or a thyroid nodule. The rapid growth of the mass raises concern for malignancy.
#
# 2. **Shortness of Breath**: This symptom may suggest that the mass is compressing the trachea or other structures in the neck, leading to respiratory difficulties.
#
# 3. **Rapid Thyroid Growth**: A rapidly enlarging thyroid gland or nodule is often associated with a higher risk of malignancy, particularly in the context of other concerning symptoms.
#
# 4. **Fever**: The presence of fever may indicate an inflammatory process, which could be associated with infection or malignancy.
#
# #### Differential Diagnosis
# Given the symptoms and clinical findings, the following differential diagnoses should be considered:
#
# 1. **Thyroid Carcinoma**: The rapid growth of the thyroid mass, along with the other symptoms, raises suspicion for a malignant thyroid tumor.
#
# 2. **Thyroiditis**: Inflammation of the thyroid gland, which can be associated with fever and neck pain, but typically does not present with rapid growth of a mass.
#
# 3. **Benign Thyroid Nodules**: While benign nodules can grow, the rapid growth and associated symptoms make this less likely.
#
# 4. **Lymphoma**: Thyroid lymphoma can present as a neck mass and may be associated with systemic symptoms like fever.
#
# #### Recommended Diagnostic Tests
# To confirm the diagnosis and assess the nature of the thyroid mass, the following tests are recommended:
#
# 1. **Thyroid Function Tests**: To evaluate the levels of thyroid hormones (TSH, T3, T4) and assess thyroid function.
#
# 2. **Ultrasound of the Neck**: To evaluate the characteristics of the thyroid mass (size, composition, vascularity) and to check for lymphadenopathy.
#
# 3. **Fine Needle Aspiration Biopsy (FNAB)**: To obtain a sample of the thyroid tissue for cytological examination to determine if the mass is malignant.
#
# 4. **CT or MRI Scan**: If there is significant compression of the trachea or other structures, imaging may be necessary to assess the extent of the mass.
#
# 5. **Thyroid Scan**: To evaluate the functional status of the thyroid nodules.
#
# #### Treatment Options
# If the diagnosis of malignant thyroid disease is confirmed, the following treatment options may be considered:
#
# 1. **Surgical Intervention**:
#    - **Thyroidectomy**: Complete or partial removal of the thyroid gland may be necessary, especially for malignant tumors.
#    - **Lymph Node Dissection**: If there is evidence of lymph node involvement.
#
# 2. **Radioactive Iodine Therapy**: This may be used post-surgery for certain types of thyroid cancer to destroy remaining cancerous cells.
#
# 3. **External Beam Radiation Therapy**: May be indicated in cases of advanced thyroid cancer.
#
# 4. **Chemotherapy**: In cases of aggressive or metastatic thyroid cancer, chemotherapy may be considered.
#
# 5. **Targeted Therapy**: For specific types of thyroid cancer, targeted therapies may be available.
#
# #### Follow-Up and Monitoring
# - Regular follow-up appointments should be scheduled to monitor thyroid function and assess for any recurrence of disease.
# - Imaging studies may be repeated as necessary to evaluate the status of the thyroid and surrounding structures.
#
# #### Conclusion
# The combination of symptoms suggests a high likelihood of malignant thyroid disease. Prompt evaluation and intervention are critical to manage the condition effectively. A multidisciplinary approach involving endocrinologists, surgeons, and oncologists may be necessary for optimal patient care.
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py:84: UserWarning: Curlm alread closed! quitting from process_data
#   self._context.run(self._callback, *self._args)
